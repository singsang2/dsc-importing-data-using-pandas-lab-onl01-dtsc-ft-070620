# %% [markdown]
# # Importing Data Using Pandas - Lab
#
# ## Introduction
#
# In this lab, you'll get some practice with loading files with summary or metadata, and if you find that easy, the optional "level up" content covers loading data from a corrupted csv file!
#
# ## Objectives
# You will be able to:
#
# - Use pandas to import data from a CSV and and an Excel spreadsheet
#
# ##  Loading Files with Summary or Meta Data
#
# Load either of the files `'Zipcode_Demos.csv'` or `'Zipcode_Demos.xlsx'`. What's going on with this dataset? Clean it up into a useable format and describe the nuances of how the data is currently formatted.
#
# All data files are stored in a folder titled `'Data'`.

# %%
# Import pandas using the standard alias
import pandas as pd

# %%
# Import the file and print the first 5 rows
df = pd.read_csv('Data/Zipcode_Demos.csv', header=47)
df.head(5)

# Excel file import
# df = pd.read_excel('Data/Zipcode_Demos.xlsx', header=48)
# df.head(5)
# Out:
#    47  JURISDICTION NAME  COUNT PARTICIPANTS  COUNT FEMALE  PERCENT FEMALE  \
# 0  48              10001                  44            22            0.50
# 1  49              10002                  35            19            0.54
# 2  50              10003                   1             1            1.00
# 3  51              10004                   0             0            0.00
# 4  52              10005                   2             2            1.00
#
#    COUNT MALE  PERCENT MALE  COUNT GENDER UNKNOWN  PERCENT GENDER UNKNOWN  \
# 0          22          0.50                     0                       0
# 1          16          0.46                     0                       0
# 2           0          0.00                     0                       0
# 3           0          0.00                     0                       0
# 4           0          0.00                     0                       0
#
#    COUNT GENDER TOTAL  ...  COUNT CITIZEN STATUS TOTAL  \
# 0                  44  ...                          44
# 1                  35  ...                          35
# 2                   1  ...                           1
# 3                   0  ...                           0
# 4                   2  ...                           2
#
#    PERCENT CITIZEN STATUS TOTAL  COUNT RECEIVES PUBLIC ASSISTANCE  \
# 0                           100                                20
# 1                           100                                 2
# 2                           100                                 0
# 3                             0                                 0
# 4                           100                                 0
#
#    PERCENT RECEIVES PUBLIC ASSISTANCE  COUNT NRECEIVES PUBLIC ASSISTANCE  \
# 0                                0.45                                 24
# 1                                0.06                                 33
# 2                                0.00                                  1
# 3                                0.00                                  0
# 4                                0.00                                  2
#
#    PERCENT NRECEIVES PUBLIC ASSISTANCE  COUNT PUBLIC ASSISTANCE UNKNOWN  \
# 0                                 0.55                                0
# 1                                 0.94                                0
# 2                                 1.00                                0
# 3                                 0.00                                0
# 4                                 1.00                                0
#
#    PERCENT PUBLIC ASSISTANCE UNKNOWN  COUNT PUBLIC ASSISTANCE TOTAL  \
# 0                                  0                             44
# 1                                  0                             35
# 2                                  0                              1
# 3                                  0                              0
# 4                                  0                              2
#
#    PERCENT PUBLIC ASSISTANCE TOTAL
# 0                              100
# 1                              100
# 2                              100
# 3                                0
# 4                              100
#
# [5 rows x 47 columns]

# %%
# Print the last 5 rows of df
df.tail(5)
# Out:
#    47  JURISDICTION NAME  COUNT PARTICIPANTS  COUNT FEMALE  PERCENT FEMALE  \
# 5  53              10006                   6             2            0.33
# 6  54              10007                   1             0            0.00
# 7  55              10009                   2             0            0.00
# 8  56              10010                   0             0            0.00
# 9  57              10011                   3             2            0.67
#
#    COUNT MALE  PERCENT MALE  COUNT GENDER UNKNOWN  PERCENT GENDER UNKNOWN  \
# 5           4          0.67                     0                       0
# 6           1          1.00                     0                       0
# 7           2          1.00                     0                       0
# 8           0          0.00                     0                       0
# 9           1          0.33                     0                       0
#
#    COUNT GENDER TOTAL  ...  COUNT CITIZEN STATUS TOTAL  \
# 5                   6  ...                           6
# 6                   1  ...                           1
# 7                   2  ...                           2
# 8                   0  ...                           0
# 9                   3  ...                           3
#
#    PERCENT CITIZEN STATUS TOTAL  COUNT RECEIVES PUBLIC ASSISTANCE  \
# 5                           100                                 0
# 6                           100                                 1
# 7                           100                                 0
# 8                             0                                 0
# 9                           100                                 0
#
#    PERCENT RECEIVES PUBLIC ASSISTANCE  COUNT NRECEIVES PUBLIC ASSISTANCE  \
# 5                                 0.0                                  6
# 6                                 1.0                                  0
# 7                                 0.0                                  2
# 8                                 0.0                                  0
# 9                                 0.0                                  3
#
#    PERCENT NRECEIVES PUBLIC ASSISTANCE  COUNT PUBLIC ASSISTANCE UNKNOWN  \
# 5                                  1.0                                0
# 6                                  0.0                                0
# 7                                  1.0                                0
# 8                                  0.0                                0
# 9                                  1.0                                0
#
#    PERCENT PUBLIC ASSISTANCE UNKNOWN  COUNT PUBLIC ASSISTANCE TOTAL  \
# 5                                  0                              6
# 6                                  0                              1
# 7                                  0                              2
# 8                                  0                              0
# 9                                  0                              3
#
#    PERCENT PUBLIC ASSISTANCE TOTAL
# 5                              100
# 6                              100
# 7                              100
# 8                                0
# 9                              100
#
# [5 rows x 47 columns]

# %%
# What is going on with this data set? Anything unusual?

# %%
# Clean up the dataset
df1 = pd.read_csv('Data/Zipcode_Demos.csv', header=0,skiprows=[1], usecols=[0,1,2], nrows=46)
df1.head()
df2 = pd.read_csv('Data/Zipcode_Demos.csv', header=47)
df2.tail()
# Out:
#    47  JURISDICTION NAME  COUNT PARTICIPANTS  COUNT FEMALE  PERCENT FEMALE  \
# 5  53              10006                   6             2            0.33
# 6  54              10007                   1             0            0.00
# 7  55              10009                   2             0            0.00
# 8  56              10010                   0             0            0.00
# 9  57              10011                   3             2            0.67
#
#    COUNT MALE  PERCENT MALE  COUNT GENDER UNKNOWN  PERCENT GENDER UNKNOWN  \
# 5           4          0.67                     0                       0
# 6           1          1.00                     0                       0
# 7           2          1.00                     0                       0
# 8           0          0.00                     0                       0
# 9           1          0.33                     0                       0
#
#    COUNT GENDER TOTAL  ...  COUNT CITIZEN STATUS TOTAL  \
# 5                   6  ...                           6
# 6                   1  ...                           1
# 7                   2  ...                           2
# 8                   0  ...                           0
# 9                   3  ...                           3
#
#    PERCENT CITIZEN STATUS TOTAL  COUNT RECEIVES PUBLIC ASSISTANCE  \
# 5                           100                                 0
# 6                           100                                 1
# 7                           100                                 0
# 8                             0                                 0
# 9                           100                                 0
#
#    PERCENT RECEIVES PUBLIC ASSISTANCE  COUNT NRECEIVES PUBLIC ASSISTANCE  \
# 5                                 0.0                                  6
# 6                                 1.0                                  0
# 7                                 0.0                                  2
# 8                                 0.0                                  0
# 9                                 0.0                                  3
#
#    PERCENT NRECEIVES PUBLIC ASSISTANCE  COUNT PUBLIC ASSISTANCE UNKNOWN  \
# 5                                  1.0                                0
# 6                                  0.0                                0
# 7                                  1.0                                0
# 8                                  0.0                                0
# 9                                  1.0                                0
#
#    PERCENT PUBLIC ASSISTANCE UNKNOWN  COUNT PUBLIC ASSISTANCE TOTAL  \
# 5                                  0                              6
# 6                                  0                              1
# 7                                  0                              2
# 8                                  0                              0
# 9                                  0                              3
#
#    PERCENT PUBLIC ASSISTANCE TOTAL
# 5                              100
# 6                              100
# 7                              100
# 8                                0
# 9                              100
#
# [5 rows x 47 columns]

# %% [markdown]
# ## Level Up (Optional) - Loading Corrupt CSV files
#
# Occasionally, you encounter some really ill-formatted data. One example of this can be data that has strings containing commas in a csv file. Under the standard protocol, when this occurs, one is supposed to use quotes to differentiate between the commas denoting fields and the commas within those fields themselves. For example, we could have a table like this:
#
# `ReviewerID,Rating,N_reviews,Review,VenueID
# 123456,4,137,This restaurant was pretty good, we had a great time.,98765`
#
# Which should be saved like this if it were a csv (to avoid confusion with the commas in the Review text):
# `"ReviewerID","Rating","N_reviews","Review","VenueID"
# "123456","4","137","This restaurant was pretty good, we had a great time.","98765"`
#
# Attempt to import the corrupt file, or at least a small preview of it. It is appropriately titled `'Yelp_Reviews_corrupt.csv'`. Investigate some of the intricacies of skipping rows to then pass over this error and comment on what you think is going on.

# %%
# Hint: Here's a useful programming pattern to use
for i in range(0,500):
    try:
        df = pd.read_csv('Data/Yelp_Reviews_corrupt.csv',header=0, nrows=i)# Do something
    except Exception as e:
        print(f'break at line {i}')
        break
print(f'break at line {i}')
df1 = pd.read_csv('Data/Yelp_Reviews_corrupt.csv',header=0, nrows=i-2)
df1.tail(20)
# Out:
# break at line 499
#                                             Unnamed: 0  \
# 477  at the dessert bar you can order fresh coffee ...
# 478        everything was really good. The place is...
# 479                                                794
# 480  great place to finish the night off or start i...
# 481                                                800
# 482                                        huge rooms
# 483                                           huge bed
# 484                                  fridge in closet
# 485                                               safe
# 486                                   lots of mirriors
# 487                               shuttle to the strip
# 488        only SEAFOOD buffet in Vegas that i know of
# 489                                  the A/C is strong
# 490  cons- resort fee unless you book with easyclic...
# 491                    carnival buffet could be better
# 492                              pool needs more shade
# 493                                                844
# 494                                                850
# 495                                                851
# 496                                                853
#
#                 business_id                    cool        date  funny  \
# 477                     NaN                     NaN         NaN    NaN
# 478                       0  D1_nrBr4dOrs7M82OaBRwQ         NaN    NaN
# 479  XXW_OFaYQkkGOGniujZFHg                       0  2013-12-04    0.0
# 480                       1  D1_nrBr4dOrs7M82OaBRwQ         NaN    NaN
# 481  xtYiHTmunjfCN2sUaQxBjA                       0  2014-08-05    0.0
# 482                     NaN                     NaN         NaN    NaN
# 483                     NaN                     NaN         NaN    NaN
# 484                     NaN                     NaN         NaN    NaN
# 485                     NaN                     NaN         NaN    NaN
# 486                     NaN                     NaN         NaN    NaN
# 487                     NaN                     NaN         NaN    NaN
# 488                     NaN                     NaN         NaN    NaN
# 489                     NaN                     NaN         NaN    NaN
# 490                     NaN                     NaN         NaN    NaN
# 491                     NaN                     NaN         NaN    NaN
# 492                       1  D1_nrBr4dOrs7M82OaBRwQ         NaN    NaN
# 493  NzWpIwYwGsjujewhYjPPPg                       0  2017-12-02    0.0
# 494  VH2BjFjc9usDquDgoHhptA                       0  2017-12-05    0.0
# 495  JlkHGjgS3MJ5FqEDJdu8xQ                       0  2015-03-05    0.0
# 496  trpn1eVgQdR1iWG6uLZrQg                       0  2012-09-15    0.0
#
#                   review_id  stars  \
# 477                     NaN    NaN
# 478                     NaN    NaN
# 479  XxsMdJl8OTgeq5iEhp4JLQ    5.0
# 480                     NaN    NaN
# 481  FvjiRz5AhudQ34C6P8YLgQ    5.0
# 482                     NaN    NaN
# 483                     NaN    NaN
# 484                     NaN    NaN
# 485                     NaN    NaN
# 486                     NaN    NaN
# 487                     NaN    NaN
# 488                     NaN    NaN
# 489                     NaN    NaN
# 490                     NaN    NaN
# 491                     NaN    NaN
# 492                     NaN    NaN
# 493  J2IFDV3oKJpTAXpW5x_PWw    1.0
# 494  TSqSiHfqtBigBa6ia59K7w    5.0
# 495  OtM6s1Y9V1EbpLp0BZnV7A    5.0
# 496  mFPOlzjmRbVWHh4E5SL-Dw    5.0
#
#                                                   text  useful  \
# 477                                                NaN     NaN
# 478                                                NaN     NaN
# 479                   this is for the fireside lounge.     NaN
# 480                                                NaN     NaN
# 481  pros-  our window was from floor to cielling a...     NaN
# 482                                                NaN     NaN
# 483                                                NaN     NaN
# 484                                                NaN     NaN
# 485                                                NaN     NaN
# 486                                                NaN     NaN
# 487                                                NaN     NaN
# 488                                                NaN     NaN
# 489                                                NaN     NaN
# 490                                                NaN     NaN
# 491                                                NaN     NaN
# 492                                                NaN     NaN
# 493  I came in to get some boba tea and there was a...     0.0
# 494  Amazing tacos! A must try if you're in the are...     0.0
# 495  I had a wonderful lunch with my mother at this...     0.0
# 496  I can't say enough good about this place. Oyst...     NaN
#
#                     user_id
# 477                     NaN
# 478                     NaN
# 479                     NaN
# 480                     NaN
# 481                     NaN
# 482                     NaN
# 483                     NaN
# 484                     NaN
# 485                     NaN
# 486                     NaN
# 487                     NaN
# 488                     NaN
# 489                     NaN
# 490                     NaN
# 491                     NaN
# 492                     NaN
# 493  0XKTRsa8Y1A3RHJB5LhuUg
# 494  SZHWhyG7WxJZdGp6fBVlRg
# 495  SZHWhyG7WxJZdGp6fBVlRg
# 496                     NaN

# %% [markdown]
# ## Summary
#
# Congratulations, you now practiced your Pandas-importing skills!
